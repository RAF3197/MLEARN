# %%
import os
import math
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import time
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
import math

# %%
# Custom Dataset
from sklearn.discriminant_analysis import StandardScaler


class CustomDataset(Dataset):
    def __init__(self, csv_path="data/dataset_train_2024.csv"):
        # Load data from CSV
        data = pd.read_csv(csv_path)
        
        # Extract features
        self.sequences_1 = data.iloc[:, 1:129].values * 100  # Columns 1-128 (1-based indexing)
        self.sequences_2 = data.iloc[:, 129:257].values * 100  # Columns 129-256
        self.extra_feature = data.iloc[:, 257].values.reshape(-1, 1)  # Column 257

        # Combine features
        all_features = np.hstack([self.sequences_1, self.sequences_2, self.extra_feature])
        
        # Normalize features
        self.scaler = StandardScaler()
        self.normalized_features = self.scaler.fit_transform(all_features)
        self.features = torch.tensor(self.normalized_features, dtype=torch.float32)


        # Encode labels
        self.label_encoder = LabelEncoder()
        self.labels = torch.tensor(self.label_encoder.fit_transform(data.iloc[:, -1]), dtype=torch.long)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]
    
    def inverseTransform(self, array):
        return self.label_encoder.inverse_transform(array)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
import numpy as np

# Load the dataset
dataset = CustomDataset(csv_path="data/dataset_train_2024.csv")
features = dataset.features.numpy()  # Convert features to NumPy array
labels = dataset.labels.numpy()  # Convert labels to NumPy array

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42, stratify=labels
)

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define SVM model and hyperparameter grid
svm = SVC()

param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'degree': [2, 3, 4],  # Only relevant for 'poly' kernel
    'gamma': ['scale', 'auto'],  # RBF/Sigmoid-specific
}

# Perform Grid Search
grid_search = GridSearchCV(svm, param_grid, scoring='accuracy', cv=5, verbose=2)
grid_search.fit(X_train, y_train)

# Best parameters and accuracy
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Cross-Validation Accuracy: {grid_search.best_score_:.4f}")

# Evaluate on the test set
best_svm = grid_search.best_estimator_
y_pred = best_svm.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=  19.4s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=  19.2s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=  18.7s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=  21.2s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=  16.9s
# [CV] END ..........C=0.1, degree=2, gamma=scale, kernel=poly; total time=   9.2s
# [CV] END ..........C=0.1, degree=2, gamma=scale, kernel=poly; total time=   9.3s
# [CV] END ..........C=0.1, degree=2, gamma=scale, kernel=poly; total time=  10.0s
# [CV] END ..........C=0.1, degree=2, gamma=scale, kernel=poly; total time=   8.8s
# [CV] END ..........C=0.1, degree=2, gamma=scale, kernel=poly; total time=   9.0s
# [CV] END ...........C=0.1, degree=2, gamma=scale, kernel=rbf; total time=  12.8s
# [CV] END ...........C=0.1, degree=2, gamma=scale, kernel=rbf; total time=  12.9s
# [CV] END ...........C=0.1, degree=2, gamma=scale, kernel=rbf; total time=  12.9s
# [CV] END ...........C=0.1, degree=2, gamma=scale, kernel=rbf; total time=  12.9s
# [CV] END ...........C=0.1, degree=2, gamma=scale, kernel=rbf; total time=  13.0s
# [CV] END .......C=0.1, degree=2, gamma=scale, kernel=sigmoid; total time=  13.0s
# [CV] END .......C=0.1, degree=2, gamma=scale, kernel=sigmoid; total time=  12.9s
# [CV] END .......C=0.1, degree=2, gamma=scale, kernel=sigmoid; total time=  15.4s
# [CV] END .......C=0.1, degree=2, gamma=scale, kernel=sigmoid; total time=  18.6s
# [CV] END .......C=0.1, degree=2, gamma=scale, kernel=sigmoid; total time=  14.4s
# [CV] END .........C=0.1, degree=2, gamma=auto, kernel=linear; total time=  19.9s
# [CV] END .........C=0.1, degree=2, gamma=auto, kernel=linear; total time=  16.2s
# [CV] END .........C=0.1, degree=2, gamma=auto, kernel=linear; total time=  13.9s
# [CV] END .........C=0.1, degree=2, gamma=auto, kernel=linear; total time=  15.1s
# [CV] END .........C=0.1, degree=2, gamma=auto, kernel=linear; total time=  16.1s
# [CV] END ...........C=0.1, degree=2, gamma=auto, kernel=poly; total time=   8.6s
# [CV] END ...........C=0.1, degree=2, gamma=auto, kernel=poly; total time=   8.6s
# [CV] END ...........C=0.1, degree=2, gamma=auto, kernel=poly; total time=   8.8s
# [CV] END ...........C=0.1, degree=2, gamma=auto, kernel=poly; total time=   8.8s
# [CV] END ...........C=0.1, degree=2, gamma=auto, kernel=poly; total time=   8.7s
# [CV] END ............C=0.1, degree=2, gamma=auto, kernel=rbf; total time=  13.2s
# [CV] END ............C=0.1, degree=2, gamma=auto, kernel=rbf; total time=  12.7s
# [CV] END ............C=0.1, degree=2, gamma=auto, kernel=rbf; total time=  13.1s
# [CV] END ............C=0.1, degree=2, gamma=auto, kernel=rbf; total time=  13.1s
# [CV] END ............C=0.1, degree=2, gamma=auto, kernel=rbf; total time=  12.6s
# [CV] END ........C=0.1, degree=2, gamma=auto, kernel=sigmoid; total time=  12.3s
# [CV] END ........C=0.1, degree=2, gamma=auto, kernel=sigmoid; total time=  12.3s
# [CV] END ........C=0.1, degree=2, gamma=auto, kernel=sigmoid; total time=  12.4s
# [CV] END ........C=0.1, degree=2, gamma=auto, kernel=sigmoid; total time=  13.0s
# [CV] END ........C=0.1, degree=2, gamma=auto, kernel=sigmoid; total time=  13.0s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=  15.2s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=  15.1s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=  15.7s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=  19.6s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=  19.8s
# [CV] END ..........C=0.1, degree=3, gamma=scale, kernel=poly; total time=  11.0s
# [CV] END ..........C=0.1, degree=3, gamma=scale, kernel=poly; total time=  11.2s
# [CV] END ..........C=0.1, degree=3, gamma=scale, kernel=poly; total time=  13.7s
# [CV] END ..........C=0.1, degree=3, gamma=scale, kernel=poly; total time=  16.2s
# [CV] END ..........C=0.1, degree=3, gamma=scale, kernel=poly; total time=  12.1s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  13.1s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  12.7s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  13.2s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  13.3s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  13.3s
# [CV] END .......C=0.1, degree=3, gamma=scale, kernel=sigmoid; total time=  13.0s
# [CV] END .......C=0.1, degree=3, gamma=scale, kernel=sigmoid; total time=  12.5s
# [CV] END .......C=0.1, degree=3, gamma=scale, kernel=sigmoid; total time=  13.1s
# [CV] END .......C=0.1, degree=3, gamma=scale, kernel=sigmoid; total time=  12.6s
# [CV] END .......C=0.1, degree=3, gamma=scale, kernel=sigmoid; total time=  12.5s
# [CV] END .........C=0.1, degree=3, gamma=auto, kernel=linear; total time=  15.2s
# [CV] END .........C=0.1, degree=3, gamma=auto, kernel=linear; total time=  15.7s
# [CV] END .........C=0.1, degree=3, gamma=auto, kernel=linear; total time=  15.7s
# [CV] END .........C=0.1, degree=3, gamma=auto, kernel=linear; total time=  15.7s
# [CV] END .........C=0.1, degree=3, gamma=auto, kernel=linear; total time=  15.8s
# [CV] END ...........C=0.1, degree=3, gamma=auto, kernel=poly; total time=  12.0s
# [CV] END ...........C=0.1, degree=3, gamma=auto, kernel=poly; total time=  12.8s
# [CV] END ...........C=0.1, degree=3, gamma=auto, kernel=poly; total time=  11.5s
# [CV] END ...........C=0.1, degree=3, gamma=auto, kernel=poly; total time=  11.1s
# [CV] END ...........C=0.1, degree=3, gamma=auto, kernel=poly; total time=  11.2s
# [CV] END ............C=0.1, degree=3, gamma=auto, kernel=rbf; total time=  12.9s
# [CV] END ............C=0.1, degree=3, gamma=auto, kernel=rbf; total time=  13.2s
# [CV] END ............C=0.1, degree=3, gamma=auto, kernel=rbf; total time=  13.1s
# [CV] END ............C=0.1, degree=3, gamma=auto, kernel=rbf; total time=  13.0s
# [CV] END ............C=0.1, degree=3, gamma=auto, kernel=rbf; total time=  13.0s
# [CV] END ........C=0.1, degree=3, gamma=auto, kernel=sigmoid; total time=  12.7s
# [CV] END ........C=0.1, degree=3, gamma=auto, kernel=sigmoid; total time=  12.8s
# [CV] END ........C=0.1, degree=3, gamma=auto, kernel=sigmoid; total time=  13.3s
# [CV] END ........C=0.1, degree=3, gamma=auto, kernel=sigmoid; total time=  16.5s
# [CV] END ........C=0.1, degree=3, gamma=auto, kernel=sigmoid; total time=  13.2s
# [CV] END ........C=0.1, degree=4, gamma=scale, kernel=linear; total time=  15.5s
# [CV] END ........C=0.1, degree=4, gamma=scale, kernel=linear; total time=  15.6s
# [CV] END ........C=0.1, degree=4, gamma=scale, kernel=linear; total time=  15.7s
# [CV] END ........C=0.1, degree=4, gamma=scale, kernel=linear; total time=  15.8s
# [CV] END ........C=0.1, degree=4, gamma=scale, kernel=linear; total time=  15.6s
# [CV] END ..........C=0.1, degree=4, gamma=scale, kernel=poly; total time=  10.4s
# [CV] END ..........C=0.1, degree=4, gamma=scale, kernel=poly; total time=  10.2s
# [CV] END ..........C=0.1, degree=4, gamma=scale, kernel=poly; total time=  10.2s
# [CV] END ..........C=0.1, degree=4, gamma=scale, kernel=poly; total time=  10.7s
# [CV] END ..........C=0.1, degree=4, gamma=scale, kernel=poly; total time=  10.3s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  13.3s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  13.1s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  13.3s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  12.8s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  13.0s
# [CV] END .......C=0.1, degree=4, gamma=scale, kernel=sigmoid; total time=  12.6s
# [CV] END .......C=0.1, degree=4, gamma=scale, kernel=sigmoid; total time=  12.7s
# [CV] END .......C=0.1, degree=4, gamma=scale, kernel=sigmoid; total time=  12.9s
# [CV] END .......C=0.1, degree=4, gamma=scale, kernel=sigmoid; total time=  12.8s
# [CV] END .......C=0.1, degree=4, gamma=scale, kernel=sigmoid; total time=  13.0s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=  15.6s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=  15.9s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=  15.6s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=  16.0s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=  16.1s
# [CV] END ...........C=0.1, degree=4, gamma=auto, kernel=poly; total time=  11.2s
# [CV] END ...........C=0.1, degree=4, gamma=auto, kernel=poly; total time=  11.4s
# [CV] END ...........C=0.1, degree=4, gamma=auto, kernel=poly; total time=  10.1s
# [CV] END ...........C=0.1, degree=4, gamma=auto, kernel=poly; total time=  10.3s
# [CV] END ...........C=0.1, degree=4, gamma=auto, kernel=poly; total time=  10.2s
# [CV] END ............C=0.1, degree=4, gamma=auto, kernel=rbf; total time=  12.8s
# [CV] END ............C=0.1, degree=4, gamma=auto, kernel=rbf; total time=  13.6s
# [CV] END ............C=0.1, degree=4, gamma=auto, kernel=rbf; total time=  16.1s
# [CV] END ............C=0.1, degree=4, gamma=auto, kernel=rbf; total time=  18.1s
# [CV] END ............C=0.1, degree=4, gamma=auto, kernel=rbf; total time=  15.7s
# [CV] END ........C=0.1, degree=4, gamma=auto, kernel=sigmoid; total time=  17.8s
# [CV] END ........C=0.1, degree=4, gamma=auto, kernel=sigmoid; total time=  13.9s
# [CV] END ........C=0.1, degree=4, gamma=auto, kernel=sigmoid; total time=  13.5s
# [CV] END ........C=0.1, degree=4, gamma=auto, kernel=sigmoid; total time=  13.2s
# [CV] END ........C=0.1, degree=4, gamma=auto, kernel=sigmoid; total time=  13.1s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=  46.6s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=  48.5s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=  46.5s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=  48.6s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=  47.7s
# [CV] END ............C=1, degree=2, gamma=scale, kernel=poly; total time=   6.9s
# [CV] END ............C=1, degree=2, gamma=scale, kernel=poly; total time=   7.1s
# [CV] END ............C=1, degree=2, gamma=scale, kernel=poly; total time=   7.1s
# [CV] END ............C=1, degree=2, gamma=scale, kernel=poly; total time=   7.2s
# [CV] END ............C=1, degree=2, gamma=scale, kernel=poly; total time=   7.1s
# [CV] END .............C=1, degree=2, gamma=scale, kernel=rbf; total time=  10.7s
# [CV] END .............C=1, degree=2, gamma=scale, kernel=rbf; total time=  11.5s
# [CV] END .............C=1, degree=2, gamma=scale, kernel=rbf; total time=  13.8s
# [CV] END .............C=1, degree=2, gamma=scale, kernel=rbf; total time=  11.8s
# [CV] END .............C=1, degree=2, gamma=scale, kernel=rbf; total time=  12.9s
# [CV] END .........C=1, degree=2, gamma=scale, kernel=sigmoid; total time=  13.5s
# [CV] END .........C=1, degree=2, gamma=scale, kernel=sigmoid; total time=  12.8s
# [CV] END .........C=1, degree=2, gamma=scale, kernel=sigmoid; total time=  12.6s
# [CV] END .........C=1, degree=2, gamma=scale, kernel=sigmoid; total time=  13.1s
# [CV] END .........C=1, degree=2, gamma=scale, kernel=sigmoid; total time=  13.4s
# [CV] END ...........C=1, degree=2, gamma=auto, kernel=linear; total time=  46.3s
# [CV] END ...........C=1, degree=2, gamma=auto, kernel=linear; total time=  48.3s
# [CV] END ...........C=1, degree=2, gamma=auto, kernel=linear; total time=  50.9s
# [CV] END ...........C=1, degree=2, gamma=auto, kernel=linear; total time=  50.9s
# [CV] END ...........C=1, degree=2, gamma=auto, kernel=linear; total time=  47.9s
# [CV] END .............C=1, degree=2, gamma=auto, kernel=poly; total time=   7.0s
# [CV] END .............C=1, degree=2, gamma=auto, kernel=poly; total time=   6.9s
# [CV] END .............C=1, degree=2, gamma=auto, kernel=poly; total time=   7.1s
# [CV] END .............C=1, degree=2, gamma=auto, kernel=poly; total time=   6.9s
# [CV] END .............C=1, degree=2, gamma=auto, kernel=poly; total time=   6.9s
# [CV] END ..............C=1, degree=2, gamma=auto, kernel=rbf; total time=  10.7s
# [CV] END ..............C=1, degree=2, gamma=auto, kernel=rbf; total time=  11.0s
# [CV] END ..............C=1, degree=2, gamma=auto, kernel=rbf; total time=  11.0s
# [CV] END ..............C=1, degree=2, gamma=auto, kernel=rbf; total time=  10.7s
# [CV] END ..............C=1, degree=2, gamma=auto, kernel=rbf; total time=  10.9s
# [CV] END ..........C=1, degree=2, gamma=auto, kernel=sigmoid; total time=  12.9s
# [CV] END ..........C=1, degree=2, gamma=auto, kernel=sigmoid; total time=  13.4s
# [CV] END ..........C=1, degree=2, gamma=auto, kernel=sigmoid; total time=  13.1s
# [CV] END ..........C=1, degree=2, gamma=auto, kernel=sigmoid; total time=  12.8s
# [CV] END ..........C=1, degree=2, gamma=auto, kernel=sigmoid; total time=  13.2s
# [CV] END ..........C=1, degree=3, gamma=scale, kernel=linear; total time=  50.0s
# [CV] END ..........C=1, degree=3, gamma=scale, kernel=linear; total time=  52.5s
# [CV] END ..........C=1, degree=3, gamma=scale, kernel=linear; total time=  46.7s
# [CV] END ..........C=1, degree=3, gamma=scale, kernel=linear; total time=  48.0s
# [CV] END ..........C=1, degree=3, gamma=scale, kernel=linear; total time=  52.7s
# [CV] END ............C=1, degree=3, gamma=scale, kernel=poly; total time=  11.8s
# [CV] END ............C=1, degree=3, gamma=scale, kernel=poly; total time=  11.2s
# [CV] END ............C=1, degree=3, gamma=scale, kernel=poly; total time=  15.8s
# [CV] END ............C=1, degree=3, gamma=scale, kernel=poly; total time=  14.9s
# [CV] END ............C=1, degree=3, gamma=scale, kernel=poly; total time=  15.8s
# [CV] END .............C=1, degree=3, gamma=scale, kernel=rbf; total time=  11.7s
# [CV] END .............C=1, degree=3, gamma=scale, kernel=rbf; total time=  10.7s
# [CV] END .............C=1, degree=3, gamma=scale, kernel=rbf; total time=  10.1s
# [CV] END .............C=1, degree=3, gamma=scale, kernel=rbf; total time=  10.1s
# [CV] END .............C=1, degree=3, gamma=scale, kernel=rbf; total time=  10.2s
# [CV] END .........C=1, degree=3, gamma=scale, kernel=sigmoid; total time=  12.3s
# [CV] END .........C=1, degree=3, gamma=scale, kernel=sigmoid; total time=  14.1s
# [CV] END .........C=1, degree=3, gamma=scale, kernel=sigmoid; total time=  17.1s
# [CV] END .........C=1, degree=3, gamma=scale, kernel=sigmoid; total time=  16.1s
# [CV] END .........C=1, degree=3, gamma=scale, kernel=sigmoid; total time=  14.8s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=  48.1s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=  46.8s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=  46.7s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=  48.0s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=  48.0s
# [CV] END .............C=1, degree=3, gamma=auto, kernel=poly; total time=  13.5s
# [CV] END .............C=1, degree=3, gamma=auto, kernel=poly; total time=  11.8s
# [CV] END .............C=1, degree=3, gamma=auto, kernel=poly; total time=  11.3s
# [CV] END .............C=1, degree=3, gamma=auto, kernel=poly; total time=  10.9s
# [CV] END .............C=1, degree=3, gamma=auto, kernel=poly; total time=  11.0s
# [CV] END ..............C=1, degree=3, gamma=auto, kernel=rbf; total time=  10.3s
# [CV] END ..............C=1, degree=3, gamma=auto, kernel=rbf; total time=  10.2s
# [CV] END ..............C=1, degree=3, gamma=auto, kernel=rbf; total time=  10.2s
# [CV] END ..............C=1, degree=3, gamma=auto, kernel=rbf; total time=  10.1s
# [CV] END ..............C=1, degree=3, gamma=auto, kernel=rbf; total time=  10.1s
# [CV] END ..........C=1, degree=3, gamma=auto, kernel=sigmoid; total time=  12.8s
# [CV] END ..........C=1, degree=3, gamma=auto, kernel=sigmoid; total time=  12.4s
# [CV] END ..........C=1, degree=3, gamma=auto, kernel=sigmoid; total time=  11.8s
# [CV] END ..........C=1, degree=3, gamma=auto, kernel=sigmoid; total time=  12.2s
# [CV] END ..........C=1, degree=3, gamma=auto, kernel=sigmoid; total time=  12.8s
# [CV] END ..........C=1, degree=4, gamma=scale, kernel=linear; total time=  50.0s
# [CV] END ..........C=1, degree=4, gamma=scale, kernel=linear; total time=  48.4s
# [CV] END ..........C=1, degree=4, gamma=scale, kernel=linear; total time=  46.5s
# [CV] END ..........C=1, degree=4, gamma=scale, kernel=linear; total time=  47.3s
# [CV] END ..........C=1, degree=4, gamma=scale, kernel=linear; total time=  47.2s
# [CV] END ............C=1, degree=4, gamma=scale, kernel=poly; total time=   9.7s
# [CV] END ............C=1, degree=4, gamma=scale, kernel=poly; total time=  10.1s
# [CV] END ............C=1, degree=4, gamma=scale, kernel=poly; total time=  11.6s
# [CV] END ............C=1, degree=4, gamma=scale, kernel=poly; total time=  11.5s
# [CV] END ............C=1, degree=4, gamma=scale, kernel=poly; total time=  10.6s
# [CV] END .............C=1, degree=4, gamma=scale, kernel=rbf; total time=  10.5s
# [CV] END .............C=1, degree=4, gamma=scale, kernel=rbf; total time=  10.6s
# [CV] END .............C=1, degree=4, gamma=scale, kernel=rbf; total time=  10.5s
# [CV] END .............C=1, degree=4, gamma=scale, kernel=rbf; total time=  10.4s
# [CV] END .............C=1, degree=4, gamma=scale, kernel=rbf; total time=  11.2s
# [CV] END .........C=1, degree=4, gamma=scale, kernel=sigmoid; total time=  17.7s
# [CV] END .........C=1, degree=4, gamma=scale, kernel=sigmoid; total time=  13.0s
# [CV] END .........C=1, degree=4, gamma=scale, kernel=sigmoid; total time=  12.6s
# [CV] END .........C=1, degree=4, gamma=scale, kernel=sigmoid; total time=  12.7s
# [CV] END .........C=1, degree=4, gamma=scale, kernel=sigmoid; total time=  13.2s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=  47.0s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=  55.5s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=  47.5s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=  52.3s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=  49.0s
# [CV] END .............C=1, degree=4, gamma=auto, kernel=poly; total time=  10.1s
# [CV] END .............C=1, degree=4, gamma=auto, kernel=poly; total time=   9.9s
# [CV] END .............C=1, degree=4, gamma=auto, kernel=poly; total time=  10.0s
# [CV] END .............C=1, degree=4, gamma=auto, kernel=poly; total time=  10.2s
# [CV] END .............C=1, degree=4, gamma=auto, kernel=poly; total time=   9.6s
# [CV] END ..............C=1, degree=4, gamma=auto, kernel=rbf; total time=  11.2s
# [CV] END ..............C=1, degree=4, gamma=auto, kernel=rbf; total time=  11.0s
# [CV] END ..............C=1, degree=4, gamma=auto, kernel=rbf; total time=  11.1s
# [CV] END ..............C=1, degree=4, gamma=auto, kernel=rbf; total time=  11.1s
# [CV] END ..............C=1, degree=4, gamma=auto, kernel=rbf; total time=  10.9s
# [CV] END ..........C=1, degree=4, gamma=auto, kernel=sigmoid; total time=  14.9s
# [CV] END ..........C=1, degree=4, gamma=auto, kernel=sigmoid; total time=  15.4s
# [CV] END ..........C=1, degree=4, gamma=auto, kernel=sigmoid; total time=  14.4s
# [CV] END ..........C=1, degree=4, gamma=auto, kernel=sigmoid; total time=  15.5s
# [CV] END ..........C=1, degree=4, gamma=auto, kernel=sigmoid; total time=  13.6s
# [CV] END .........C=10, degree=2, gamma=scale, kernel=linear; total time= 9.6min
# [CV] END .........C=10, degree=2, gamma=scale, kernel=linear; total time= 8.4min
# [CV] END .........C=10, degree=2, gamma=scale, kernel=linear; total time= 8.1min
