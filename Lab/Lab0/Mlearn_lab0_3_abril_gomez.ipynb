# %% [markdown]
# We import the libs to analyze the dataset

# %%
import numpy as np              #import numpy with the alias np
import matplotlib.pyplot as plt #import matplotlib.pyplot with the alias plt
import pandas as pd             #import pandas with the alias pd
import seaborn as sns           #import seaborn with the alias sns
import scipy.stats as ss
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np              #import numpy with the alias np
#       2 import matplotlib.pyplot as plt #import matplotlib.pyplot with the alias plt
#       3 import pandas as pd             #import pandas with the alias pd
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# We read the CSV then we calculate the mean and CI's 'manually'
#
# 1. Choose a feature.
# 2. Iterate over classes
# 3. Compute mean for that class and feature
# 4. Compute standard deviation for that class and feature
# 5. Iterate over alpha values.
# 6. Compute t-critical value using ppf function.
# 7. Compute standard error for the mean.
# 8. Compute confidence intervals

# %%
iris = pd.read_csv("iris.csv")

species = iris['species'].unique()
confidenceLevels = [0.95, 0.99, 0.999]

for s in species:
    print("Specie: " + s + "\n")
    petal_lenght = iris[iris["species"]==s]['petal_lenght']
    mean = np.mean(petal_lenght)
    standard = np.std(petal_lenght)

    print("mean -> " + mean + "\n")
    print("std -> " + standard + "\n")
    
    for confidence in confidenceLevels:

        t = ss.t.ppf((1 - confidence) / 2, len(petal_lenght) - 1)

        sem = standard / np.sqrt(len(petal_lenght))
        ci_lower = mean - t * sem
        ci_upper = mean + t * sem

        print("ci " + confidence + " -> (", ci_lower + ", " + ci_upper)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 50%        5.800000     3.000000      4.350000     1.300000
# 95%        7.255000     3.800000      6.100000     2.300000
# 99%        7.700000     4.151000      6.700000     2.500000
# 99.9%      7.870200     4.370200      6.870200     2.500000
# max        7.900000     4.400000      6.900000     2.500000
